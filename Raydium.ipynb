# %% [markdown]
# <a href="https://colab.research.google.com/github/abhy-kumar/Raydium/blob/main/Raydium.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install geopandas folium pvlib requests beautifulsoup4
# Out:
# Requirement already satisfied: geopandas in /usr/local/lib/python3.10/dist-packages (1.0.1)
# Requirement already satisfied: folium in /usr/local/lib/python3.10/dist-packages (0.18.0)
# Collecting pvlib
#   Downloading pvlib-0.11.1-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.12.3)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.26.4)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.10/dist-packages (from geopandas) (0.10.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from geopandas) (24.1)
# Requirement already satisfied: pandas>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from geopandas) (2.2.2)
# Requirement already satisfied: pyproj>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from geopandas) (3.7.0)
# Requirement already satisfied: shapely>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from geopandas) (2.0.6)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from folium) (0.8.0)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from folium) (3.1.4)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.10/dist-packages (from folium) (2024.9.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from pvlib) (2024.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from pvlib) (1.13.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from pvlib) (3.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.8.30)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4.0->geopandas) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4.0->geopandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->geopandas) (1.16.0)
# Downloading pvlib-0.11.1-py3-none-any.whl (29.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.5/29.5 MB 58.8 MB/s eta 0:00:00
# Installing collected packages: pvlib
# Successfully installed pvlib-0.11.1

# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import folium
from folium import plugins
import requests
from scipy.interpolate import griddata
import time

def fetch_nasa_power_data(lat, lon):
    """
    Fetch solar radiation data from NASA POWER API
    """
    base_url = "https://power.larc.nasa.gov/api/temporal/daily/point"
    params = {
        'parameters': 'ALLSKY_SFC_SW_DWN',
        'community': 'RE',
        'longitude': str(lon),
        'latitude': str(lat),
        'start': '20230101',
        'end': '20231231',
        'format': 'JSON'
    }

    try:
        response = requests.get(base_url, params=params)
        response.raise_for_status()
        data = response.json()
        return data
    except requests.exceptions.RequestException as e:
        print(f"Error making request: {e}")
        return None
    except ValueError as e:
        print(f"Error parsing JSON: {e}")
        return None

def calculate_solar_potential(power_data, panel_efficiency=0.2):
    """
    Calculate solar potential based on radiation data
    """
    if power_data is None:
        return None

    try:
        daily_data = power_data.get('properties', {}).get('parameter', {}).get('ALLSKY_SFC_SW_DWN', {})

        if not daily_data:
            print("No daily data found in response")
            return None

        radiation_values = []
        for value in daily_data.values():
            if isinstance(value, (int, float)) and value != -999:
                radiation_values.append(value * 0.277778)  # Convert MJ to kWh

        if not radiation_values:
            print("No valid radiation values found")
            return None

        annual_potential = np.mean(radiation_values) * 365 * panel_efficiency
        return annual_potential

    except (KeyError, TypeError) as e:
        print(f"Error processing data: {e}")
        return None

def create_india_solar_map(geojson_path):
    """
    Create an interactive map of India's solar potential with interpolated contours
    """
    # Read India GeoJSON
    india = gpd.read_file(geojson_path)

    # Print GeoJSON properties to inspect structure
    print("GeoJSON properties available:", list(india.columns))

    # Create a base map centered on India
    m = folium.Map(location=[20.5937, 78.9629], zoom_start=5)

    # Create a grid for sampling points
    lat_range = np.arange(8.4, 37.6, 0.5)
    lon_range = np.arange(68.7, 97.25, 0.5)

    # Store solar potential data
    solar_data = []

    # Fetch data for each grid point
    total_points = len(lat_range) * len(lon_range)
    current_point = 0

    for lat in lat_range:
        for lon in lon_range:
            current_point += 1
            print(f"\nProcessing point {current_point}/{total_points}")

            point = gpd.points_from_xy([lon], [lat])[0]

            # Check if point is within India
            if any(india.contains(point)):
                power_data = fetch_nasa_power_data(lat, lon)
                time.sleep(1)

                if power_data:
                    potential = calculate_solar_potential(power_data)
                    if potential is not None:
                        solar_data.append({
                            'latitude': lat,
                            'longitude': lon,
                            'potential': potential
                        })

    # Create DataFrame from collected data
    solar_df = pd.DataFrame(solar_data)

    # Create a finer mesh grid for interpolation
    grid_lat = np.linspace(solar_df['latitude'].min(), solar_df['latitude'].max(), 200)
    grid_lon = np.linspace(solar_df['longitude'].min(), solar_df['longitude'].max(), 200)
    grid_lon, grid_lat = np.meshgrid(grid_lon, grid_lat)

    # Interpolate the data
    points = solar_df[['longitude', 'latitude']].values
    values = solar_df['potential'].values
    grid_z = griddata(points, values, (grid_lon, grid_lat), method='cubic')

    # Create contour data
    contour_data = []
    for i in range(len(grid_lat)):
        for j in range(len(grid_lon)):
            if not np.isnan(grid_z[i, j]):
                point = gpd.points_from_xy([grid_lon[i, j]], [grid_lat[i, j]])[0]
                if any(india.contains(point)):
                    contour_data.append([
                        grid_lat[i, j],
                        grid_lon[i, j],
                        grid_z[i, j]
                    ])

    # Convert to numpy array for easier manipulation
    contour_array = np.array(contour_data)

    # Get actual min and max values for India
    min_val = np.min(contour_array[:, 2])
    max_val = np.max(contour_array[:, 2])

    # Modified Choropleth layer
    choropleth = folium.Choropleth(
        geo_data=india.__geo_interface__,  # Use the complete GeoJSON interface
        data=solar_df,
        columns=['latitude', 'potential'],
        key_on='geometry',  # Changed from 'feature.properties.name'
        fill_color='YlOrRd',
        fill_opacity=0.7,
        line_opacity=0.2,
        legend_name='Solar Potential (kWh/m²/year)',
        smooth_factor=0
    ).add_to(m)

    # Add GeoJSON boundary
    folium.GeoJson(
        india,
        style_function=lambda x: {
            'fillColor': 'none',
            'color': 'black',
            'weight': 1.5
        }
    ).add_to(m)

    # Add detailed legend with actual values
    legend_html = f'''
        <div style="position: fixed;
                    bottom: 50px; right: 50px; width: 250px;
                    border:2px solid grey; z-index:9999; font-size:14px;
                    background-color:white;
                    padding: 10px;
                    border-radius: 5px;">
        <p style="margin: 0 0 5px 0;"><strong>Solar Potential (kWh/m²/year)</strong></p>
        <table style="width:100%; border-collapse: collapse;">
    '''

    # Add color gradient and value ranges
    colors = ['#ffffb2', '#fecc5c', '#fd8d3c', '#f03b20', '#bd0026']
    step = (max_val - min_val) / len(colors)
    for i, color in enumerate(colors):
        value = min_val + i * step
        legend_html += f'''
            <tr>
                <td style="width:30px; background-color:{color}; height:20px;"></td>
                <td style="padding-left:10px;">{value:.0f} - {value + step:.0f}</td>
            </tr>
        '''

    legend_html += '''
        </table>
        </div>
    '''

    m.get_root().html.add_child(folium.Element(legend_html))

    # Save the solar potential data
    solar_df.to_csv('india_solar_data.csv', index=False)

    return m, solar_df

def main():
    """
    Main function to run the application
    """
    geojson_path = 'india-soi.geojson'

    try:
        print("Creating India's solar potential map...")
        solar_map, solar_data = create_india_solar_map(geojson_path)
        solar_map.save('india_solar_potential.html')
        print("\nMap has been generated and saved as 'india_solar_potential.html'")
        print("Raw data has been saved as 'india_solar_data.csv'")

    except Exception as e:
        print(f"An error occurred: {e}")

if __name__ == "__main__":
    main()
# Out:
# Creating India's solar potential map...
# GeoJSON properties available: ['Source', 'geometry']
#
# Processing point 1/3422
#
# Processing point 2/3422
#
# Processing point 3/3422
#
# Processing point 4/3422
#
# Processing point 5/3422
#
# Processing point 6/3422
#
# Processing point 7/3422
#
# Processing point 8/3422
#
# Processing point 9/3422
#
# Processing point 10/3422
#
# Processing point 11/3422
#
# Processing point 12/3422
#
# Processing point 13/3422
#
# Processing point 14/3422
#
# Processing point 15/3422
#
# Processing point 16/3422
#
# Processing point 17/3422
#
# Processing point 18/3422
#
# Processing point 19/3422
#
# Processing point 20/3422
#
# Processing point 21/3422
#
# Processing point 22/3422
#
# Processing point 23/3422
#
# Processing point 24/3422
#
# Processing point 25/3422
#
# Processing point 26/3422
#
# Processing point 27/3422
#
# Processing point 28/3422
#
# Processing point 29/3422
#
# Processing point 30/3422
#
# Processing point 31/3422
#
# Processing point 32/3422
#
# Processing point 33/3422
#
# Processing point 34/3422
#
# Processing point 35/3422
#
# Processing point 36/3422
#
# Processing point 37/3422
#
# Processing point 38/3422
#
# Processing point 39/3422
#
# Processing point 40/3422
#
# Processing point 41/3422
#
# Processing point 42/3422
#
# Processing point 43/3422
#
# Processing point 44/3422
#
# Processing point 45/3422
#
# Processing point 46/3422
#
# Processing point 47/3422
#
# Processing point 48/3422
#
# Processing point 49/3422
#
# Processing point 50/3422
#
# Processing point 51/3422
#
# Processing point 52/3422
#
# Processing point 53/3422
#
# Processing point 54/3422
#
# Processing point 55/3422
#
# Processing point 56/3422
#
# Processing point 57/3422
#
# Processing point 58/3422
#
# Processing point 59/3422
#
# Processing point 60/3422
#
# Processing point 61/3422
#
# Processing point 62/3422
#
# Processing point 63/3422
#
# Processing point 64/3422
#
# Processing point 65/3422
#
# Processing point 66/3422
#
# Processing point 67/3422
#
# Processing point 68/3422
#
# Processing point 69/3422
#
# Processing point 70/3422
#
# Processing point 71/3422
#
# Processing point 72/3422
#
# Processing point 73/3422
#
# Processing point 74/3422
#
# Processing point 75/3422
#
# Processing point 76/3422
#
# Processing point 77/3422
#
# Processing point 78/3422
#
# Processing point 79/3422
#
# Processing point 80/3422
#
# Processing point 81/3422
#
# Processing point 82/3422
#
# Processing point 83/3422
#
# Processing point 84/3422
#
# Processing point 85/3422
#
# Processing point 86/3422
#
# Processing point 87/3422
#
# Processing point 88/3422
#
# Processing point 89/3422
#
# Processing point 90/3422
#
# Processing point 91/3422
#
# Processing point 92/3422
#
# Processing point 93/3422
#
# Processing point 94/3422
#
# Processing point 95/3422
#
# Processing point 96/3422
#
# Processing point 97/3422
#
# Processing point 98/3422
#
# Processing point 99/3422
#
# Processing point 100/3422
#
# Processing point 101/3422
#
# Processing point 102/3422
#
# Processing point 103/3422
#
# Processing point 104/3422
#
# Processing point 105/3422
#
# Processing point 106/3422
#
# Processing point 107/3422
#
# Processing point 108/3422
#
# Processing point 109/3422
#
# Processing point 110/3422
#
# Processing point 111/3422
#
# Processing point 112/3422
#
# Processing point 113/3422
#
# Processing point 114/3422
#
# Processing point 115/3422
#
# Processing point 116/3422
#
# Processing point 117/3422
#
# Processing point 118/3422
#
# Processing point 119/3422
#
# Processing point 120/3422
#
# Processing point 121/3422
#
# Processing point 122/3422
#
# Processing point 123/3422
#
# Processing point 124/3422
#
# Processing point 125/3422
#
# Processing point 126/3422
#
# Processing point 127/3422
#
# Processing point 128/3422
#
# Processing point 129/3422
#
# Processing point 130/3422
#
# Processing point 131/3422
#
# Processing point 132/3422
#
# Processing point 133/3422
#
# Processing point 134/3422
#
# Processing point 135/3422
#
# Processing point 136/3422
#
# Processing point 137/3422
#
# Processing point 138/3422
#
# Processing point 139/3422
#
# Processing point 140/3422
#
# Processing point 141/3422
#
# Processing point 142/3422
#
# Processing point 143/3422
#
# Processing point 144/3422
#
# Processing point 145/3422
#
# Processing point 146/3422
#
# Processing point 147/3422
#
# Processing point 148/3422
#
# Processing point 149/3422
#
# Processing point 150/3422
#
# Processing point 151/3422
#
# Processing point 152/3422
#
# Processing point 153/3422
#
# Processing point 154/3422
#
# Processing point 155/3422
#
# Processing point 156/3422
#
# Processing point 157/3422
#
# Processing point 158/3422
#
# Processing point 159/3422
#
# Processing point 160/3422
#
# Processing point 161/3422
#
# Processing point 162/3422
#
# Processing point 163/3422
#
# Processing point 164/3422
#
# Processing point 165/3422
#
# Processing point 166/3422
#
# Processing point 167/3422
#
# Processing point 168/3422
#
# Processing point 169/3422
#
# Processing point 170/3422
#
# Processing point 171/3422
#
# Processing point 172/3422
#
# Processing point 173/3422
#
# Processing point 174/3422
#
# Processing point 175/3422
#
# Processing point 176/3422
#
# Processing point 177/3422
#
# Processing point 178/3422
#
# Processing point 179/3422
#
# Processing point 180/3422
#
# Processing point 181/3422
#
# Processing point 182/3422
#
# Processing point 183/3422
#
# Processing point 184/3422
#
# Processing point 185/3422
#
# Processing point 186/3422
#
# Processing point 187/3422
#
# Processing point 188/3422
#
# Processing point 189/3422
#
# Processing point 190/3422
#
# Processing point 191/3422
#
# Processing point 192/3422
#
# Processing point 193/3422
#
# Processing point 194/3422
#
# Processing point 195/3422
#
# Processing point 196/3422
#
# Processing point 197/3422
#
# Processing point 198/3422
#
# Processing point 199/3422
#
# Processing point 200/3422
#
# Processing point 201/3422
#
# Processing point 202/3422
#
# Processing point 203/3422
#
# Processing point 204/3422
#
# Processing point 205/3422
#
# Processing point 206/3422
#
# Processing point 207/3422
#
# Processing point 208/3422
#
# Processing point 209/3422
#
# Processing point 210/3422
#
# Processing point 211/3422
#
# Processing point 212/3422
#
# Processing point 213/3422
#
# Processing point 214/3422
#
# Processing point 215/3422
#
# Processing point 216/3422
#
# Processing point 217/3422
#
# Processing point 218/3422
#
# Processing point 219/3422
#
# Processing point 220/3422
#
# Processing point 221/3422
#
# Processing point 222/3422
#
# Processing point 223/3422
#
# Processing point 224/3422
#
# Processing point 225/3422
#
# Processing point 226/3422
#
# Processing point 227/3422
#
# Processing point 228/3422
#
# Processing point 229/3422
#
# Processing point 230/3422
#
# Processing point 231/3422
#
# Processing point 232/3422
#
# Processing point 233/3422
#
# Processing point 234/3422
#
# Processing point 235/3422
#
# Processing point 236/3422
#
# Processing point 237/3422
#
# Processing point 238/3422
#
# Processing point 239/3422
#
# Processing point 240/3422
#
# Processing point 241/3422
#
# Processing point 242/3422
#
# Processing point 243/3422
#
# Processing point 244/3422
#
# Processing point 245/3422
#
# Processing point 246/3422
#
# Processing point 247/3422
#
# Processing point 248/3422
#
# Processing point 249/3422
#
# Processing point 250/3422
#
# Processing point 251/3422
#
# Processing point 252/3422
#
# Processing point 253/3422
#
# Processing point 254/3422
#
# Processing point 255/3422
#
# Processing point 256/3422
#
# Processing point 257/3422
#
# Processing point 258/3422
#
# Processing point 259/3422
#
# Processing point 260/3422
#
# Processing point 261/3422
#
# Processing point 262/3422
#
# Processing point 263/3422
#
# Processing point 264/3422
#
# Processing point 265/3422
#
# Processing point 266/3422
#
# Processing point 267/3422
#
# Processing point 268/3422
#
# Processing point 269/3422
#
# Processing point 270/3422
#
# Processing point 271/3422
#
# Processing point 272/3422
#
# Processing point 273/3422
#
# Processing point 274/3422
#
# Processing point 275/3422
#
# Processing point 276/3422
#
# Processing point 277/3422
#
# Processing point 278/3422
#
# Processing point 279/3422
#
# Processing point 280/3422
#
# Processing point 281/3422
#
# Processing point 282/3422
#
# Processing point 283/3422
#
# Processing point 284/3422
#
# Processing point 285/3422
#
# Processing point 286/3422
#
# Processing point 287/3422
#
# Processing point 288/3422
#
# Processing point 289/3422
#
# Processing point 290/3422
#
# Processing point 291/3422
#
# Processing point 292/3422
#
# Processing point 293/3422
#
# Processing point 294/3422
#
# Processing point 295/3422
#
# Processing point 296/3422
#
# Processing point 297/3422
#
# Processing point 298/3422
#
# Processing point 299/3422
#
# Processing point 300/3422
#
# Processing point 301/3422
#
# Processing point 302/3422
#
# Processing point 303/3422
#
# Processing point 304/3422
#
# Processing point 305/3422
#
# Processing point 306/3422
#
# Processing point 307/3422
#
# Processing point 308/3422
#
# Processing point 309/3422
#
# Processing point 310/3422
#
# Processing point 311/3422
#
# Processing point 312/3422
#
# Processing point 313/3422
#
# Processing point 314/3422
#
# Processing point 315/3422
#
# Processing point 316/3422
#
# Processing point 317/3422
#
# Processing point 318/3422
#
# Processing point 319/3422
#
# Processing point 320/3422
#
# Processing point 321/3422
#
# Processing point 322/3422
#
# Processing point 323/3422
#
# Processing point 324/3422
#
# Processing point 325/3422
#
# Processing point 326/3422
#
# Processing point 327/3422
#
# Processing point 328/3422
#
# Processing point 329/3422
#
# Processing point 330/3422
#
# Processing point 331/3422
#
# Processing point 332/3422
#
# Processing point 333/3422
#
# Processing point 334/3422
#
# Processing point 335/3422
#
# Processing point 336/3422
#
# Processing point 337/3422
#
# Processing point 338/3422
#
# Processing point 339/3422
#
# Processing point 340/3422
#
# Processing point 341/3422
#
# Processing point 342/3422
#
# Processing point 343/3422
#
# Processing point 344/3422
#
# Processing point 345/3422
#
# Processing point 346/3422
#
# Processing point 347/3422
#
# Processing point 348/3422
#
# Processing point 349/3422
#
# Processing point 350/3422
#
# Processing point 351/3422
#
# Processing point 352/3422
#
# Processing point 353/3422
#
# Processing point 354/3422
#
# Processing point 355/3422
#
# Processing point 356/3422
#
# Processing point 357/3422
#
# Processing point 358/3422
#
# Processing point 359/3422
#
# Processing point 360/3422
#
# Processing point 361/3422
#
# Processing point 362/3422
#
# Processing point 363/3422
#
# Processing point 364/3422
#
# Processing point 365/3422
#
# Processing point 366/3422
#
# Processing point 367/3422
#
# Processing point 368/3422
#
# Processing point 369/3422
#
# Processing point 370/3422
#
# Processing point 371/3422
#
# Processing point 372/3422
#
# Processing point 373/3422
#
# Processing point 374/3422
#
# Processing point 375/3422
#
# Processing point 376/3422
#
# Processing point 377/3422
#
# Processing point 378/3422
#
# Processing point 379/3422
#
# Processing point 380/3422
#
# Processing point 381/3422
#
# Processing point 382/3422
#
# Processing point 383/3422
#
# Processing point 384/3422
#
# Processing point 385/3422
#
# Processing point 386/3422
#
# Processing point 387/3422
#
# Processing point 388/3422
#
# Processing point 389/3422
#
# Processing point 390/3422
#
# Processing point 391/3422
#
# Processing point 392/3422
#
# Processing point 393/3422
#
# Processing point 394/3422
#
# Processing point 395/3422
#
# Processing point 396/3422
#
# Processing point 397/3422
#
# Processing point 398/3422
#
# Processing point 399/3422
#
# Processing point 400/3422
#
# Processing point 401/3422
#
# Processing point 402/3422
#
# Processing point 403/3422
#
# Processing point 404/3422
#
# Processing point 405/3422
#
# Processing point 406/3422
#
# Processing point 407/3422
#
# Processing point 408/3422
#
# Processing point 409/3422
#
# Processing point 410/3422
#
# Processing point 411/3422
#
# Processing point 412/3422
#
# Processing point 413/3422
#
# Processing point 414/3422
#
# Processing point 415/3422
#
# Processing point 416/3422
#
# Processing point 417/3422
#
# Processing point 418/3422
#
# Processing point 419/3422
#
# Processing point 420/3422
#
# Processing point 421/3422
#
# Processing point 422/3422
#
# Processing point 423/3422
#
# Processing point 424/3422
#
# Processing point 425/3422
#
# Processing point 426/3422
#
# Processing point 427/3422
#
# Processing point 428/3422
#
# Processing point 429/3422
#
# Processing point 430/3422
#
# Processing point 431/3422
#
# Processing point 432/3422
#
# Processing point 433/3422
#
# Processing point 434/3422
#
# Processing point 435/3422
#
# Processing point 436/3422
#
# Processing point 437/3422
#
# Processing point 438/3422
#
# Processing point 439/3422
#
# Processing point 440/3422
#
# Processing point 441/3422
#
# Processing point 442/3422
#
# Processing point 443/3422
#
# Processing point 444/3422
#
# Processing point 445/3422
#
# Processing point 446/3422
#
# Processing point 447/3422
#
# Processing point 448/3422
#
# Processing point 449/3422
#
# Processing point 450/3422
#
# Processing point 451/3422
#
# Processing point 452/3422
#
# Processing point 453/3422
#
# Processing point 454/3422
#
# Processing point 455/3422
#
# Processing point 456/3422
#
# Processing point 457/3422
#
# Processing point 458/3422
#
# Processing point 459/3422
#
# Processing point 460/3422
#
# Processing point 461/3422
#
# Processing point 462/3422
#
# Processing point 463/3422
#
# Processing point 464/3422
#
# Processing point 465/3422
#
# Processing point 466/3422
#
# Processing point 467/3422
#
# Processing point 468/3422
#
# Processing point 469/3422
#
# Processing point 470/3422
#
# Processing point 471/3422
#
# Processing point 472/3422
#
# Processing point 473/3422
#
# Processing point 474/3422
#
# Processing point 475/3422
#
# Processing point 476/3422
#
# Processing point 477/3422
#
# Processing point 478/3422
#
# Processing point 479/3422
#
# Processing point 480/3422
#
# Processing point 481/3422
#
# Processing point 482/3422
#
# Processing point 483/3422
#
# Processing point 484/3422
#
# Processing point 485/3422
#
# Processing point 486/3422
#
# Processing point 487/3422
#
# Processing point 488/3422
#
# Processing point 489/3422
#
# Processing point 490/3422
#
# Processing point 491/3422
#
# Processing point 492/3422
#
# Processing point 493/3422
#
# Processing point 494/3422
#
# Processing point 495/3422
#
# Processing point 496/3422
#
# Processing point 497/3422
#
# Processing point 498/3422
#
# Processing point 499/3422
#
# Processing point 500/3422
#
# Processing point 501/3422
#
# Processing point 502/3422
#
# Processing point 503/3422
#
# Processing point 504/3422
#
# Processing point 505/3422
#
# Processing point 506/3422
#
# Processing point 507/3422
#
# Processing point 508/3422
#
# Processing point 509/3422
#
# Processing point 510/3422
#
# Processing point 511/3422
#
# Processing point 512/3422
#
# Processing point 513/3422
#
# Processing point 514/3422
#
# Processing point 515/3422
#
# Processing point 516/3422
#
# Processing point 517/3422
#
# Processing point 518/3422
#
# Processing point 519/3422
#
# Processing point 520/3422
#
# Processing point 521/3422
#
# Processing point 522/3422
#
# Processing point 523/3422
#
# Processing point 524/3422
#
# Processing point 525/3422
#
# Processing point 526/3422
#
# Processing point 527/3422
#
# Processing point 528/3422
#
# Processing point 529/3422
#
# Processing point 530/3422
#
# Processing point 531/3422
#
# Processing point 532/3422
#
# Processing point 533/3422
#
# Processing point 534/3422
#
# Processing point 535/3422
#
# Processing point 536/3422
#
# Processing point 537/3422
#
# Processing point 538/3422
#
# Processing point 539/3422
#
# Processing point 540/3422
#
# Processing point 541/3422
#
# Processing point 542/3422
#
# Processing point 543/3422
#
# Processing point 544/3422
#
# Processing point 545/3422
#
# Processing point 546/3422
#
# Processing point 547/3422
#
# Processing point 548/3422
#
# Processing point 549/3422
#
# Processing point 550/3422
#
# Processing point 551/3422
#
# Processing point 552/3422
#
# Processing point 553/3422
#
# Processing point 554/3422
#
# Processing point 555/3422
#
# Processing point 556/3422
#
# Processing point 557/3422
#
# Processing point 558/3422
#
# Processing point 559/3422
#
# Processing point 560/3422
#
# Processing point 561/3422
#
# Processing point 562/3422
#
# Processing point 563/3422
#
# Processing point 564/3422
#
# Processing point 565/3422
#
# Processing point 566/3422
#
# Processing point 567/3422
#
# Processing point 568/3422
#
# Processing point 569/3422
#
# Processing point 570/3422
#
# Processing point 571/3422
#
# Processing point 572/3422
#
# Processing point 573/3422
#
# Processing point 574/3422
#
# Processing point 575/3422
#
# Processing point 576/3422
#
# Processing point 577/3422
#
# Processing point 578/3422
#
# Processing point 579/3422
#
# Processing point 580/3422
#
# Processing point 581/3422
#
# Processing point 582/3422
#
# Processing point 583/3422
#
# Processing point 584/3422
#
# Processing point 585/3422
#
# Processing point 586/3422
#
# Processing point 587/3422
#
# Processing point 588/3422
#
# Processing point 589/3422
#
# Processing point 590/3422
#
# Processing point 591/3422
#
# Processing point 592/3422
#
# Processing point 593/3422
#
# Processing point 594/3422
#
# Processing point 595/3422
#
# Processing point 596/3422
#
# Processing point 597/3422
#
# Processing point 598/3422
#
# Processing point 599/3422
#
# Processing point 600/3422
#
# Processing point 601/3422
#
# Processing point 602/3422
#
# Processing point 603/3422
#
# Processing point 604/3422
#
# Processing point 605/3422
#
# Processing point 606/3422
#
# Processing point 607/3422
#
# Processing point 608/3422
#
# Processing point 609/3422
#
# Processing point 610/3422
#
# Processing point 611/3422
#
# Processing point 612/3422
#
# Processing point 613/3422
#
# Processing point 614/3422
#
# Processing point 615/3422
#
# Processing point 616/3422
#
# Processing point 617/3422
#
# Processing point 618/3422
#
# Processing point 619/3422
#
# Processing point 620/3422
#
# Processing point 621/3422
#
# Processing point 622/3422
#
# Processing point 623/3422
#
# Processing point 624/3422
#
# Processing point 625/3422
#
# Processing point 626/3422
#
# Processing point 627/3422
#
# Processing point 628/3422
#
# Processing point 629/3422
#
# Processing point 630/3422
#
# Processing point 631/3422
#
# Processing point 632/3422
#
# Processing point 633/3422
#
# Processing point 634/3422
#
# Processing point 635/3422
#
# Processing point 636/3422
#
# Processing point 637/3422
#
# Processing point 638/3422
#
# Processing point 639/3422
#
# Processing point 640/3422
#
# Processing point 641/3422
#
# Processing point 642/3422
#
# Processing point 643/3422
#
# Processing point 644/3422
#
# Processing point 645/3422
#
# Processing point 646/3422
#
# Processing point 647/3422
#
# Processing point 648/3422
#
# Processing point 649/3422
#
# Processing point 650/3422
#
# Processing point 651/3422
#
# Processing point 652/3422
#
# Processing point 653/3422
#
# Processing point 654/3422
#
# Processing point 655/3422
#
# Processing point 656/3422
#
# Processing point 657/3422
#
# Processing point 658/3422
#
# Processing point 659/3422
#
# Processing point 660/3422
#
# Processing point 661/3422
#
# Processing point 662/3422
#
# Processing point 663/3422
#
# Processing point 664/3422
#
# Processing point 665/3422
#
# Processing point 666/3422
#
# Processing point 667/3422
#
# Processing point 668/3422
#
# Processing point 669/3422
#
# Processing point 670/3422
#
# Processing point 671/3422
#
# Processing point 672/3422
#
# Processing point 673/3422
#
# Processing point 674/3422
#
# Processing point 675/3422
#
# Processing point 676/3422
#
# Processing point 677/3422
#
# Processing point 678/3422
#
# Processing point 679/3422
#
# Processing point 680/3422
#
# Processing point 681/3422
#
# Processing point 682/3422
#
# Processing point 683/3422
#
# Processing point 684/3422
#
# Processing point 685/3422
#
# Processing point 686/3422
#
# Processing point 687/3422
#
# Processing point 688/3422
#
# Processing point 689/3422
#
# Processing point 690/3422
#
# Processing point 691/3422
#
# Processing point 692/3422
#
# Processing point 693/3422
#
# Processing point 694/3422
#
# Processing point 695/3422
#
# Processing point 696/3422
#
# Processing point 697/3422
#
# Processing point 698/3422
#
# Processing point 699/3422
#
# Processing point 700/3422
#
# Processing point 701/3422
#
# Processing point 702/3422
#
# Processing point 703/3422
#
# Processing point 704/3422
#
# Processing point 705/3422
#
# Processing point 706/3422
#
# Processing point 707/3422
#
# Processing point 708/3422
#
# Processing point 709/3422
#
# Processing point 710/3422
#
# Processing point 711/3422
#
# Processing point 712/3422
#
# Processing point 713/3422
#
# Processing point 714/3422
#
# Processing point 715/3422
#
# Processing point 716/3422
#
# Processing point 717/3422
#
# Processing point 718/3422
#
# Processing point 719/3422
#
# Processing point 720/3422
#
# Processing point 721/3422
#
# Processing point 722/3422
#
# Processing point 723/3422
#
# Processing point 724/3422
#
# Processing point 725/3422
#
# Processing point 726/3422
#
# Processing point 727/3422
#
# Processing point 728/3422
#
# Processing point 729/3422
#
# Processing point 730/3422
#
# Processing point 731/3422
#
# Processing point 732/3422
#
# Processing point 733/3422
#
# Processing point 734/3422
#
# Processing point 735/3422
#
# Processing point 736/3422
#
# Processing point 737/3422
#
# Processing point 738/3422
#
# Processing point 739/3422
#
# Processing point 740/3422
#
# Processing point 741/3422
#
# Processing point 742/3422
#
# Processing point 743/3422
#
# Processing point 744/3422
#
# Processing point 745/3422
#
# Processing point 746/3422
#
# Processing point 747/3422
#
# Processing point 748/3422
#
# Processing point 749/3422
#
# Processing point 750/3422
#
# Processing point 751/3422
#
# Processing point 752/3422
#
# Processing point 753/3422
#
# Processing point 754/3422
#
# Processing point 755/3422
#
# Processing point 756/3422
#
# Processing point 757/3422
#
# Processing point 758/3422
#
# Processing point 759/3422
#
# Processing point 760/3422
#
# Processing point 761/3422
#
# Processing point 762/3422
#
# Processing point 763/3422
#
# Processing point 764/3422
#
# Processing point 765/3422
#
# Processing point 766/3422
#
# Processing point 767/3422
#
# Processing point 768/3422
#
# Processing point 769/3422
#
# Processing point 770/3422
#
# Processing point 771/3422
#
# Processing point 772/3422
#
# Processing point 773/3422
#
# Processing point 774/3422
#
# Processing point 775/3422
#
# Processing point 776/3422
#
# Processing point 777/3422
#
# Processing point 778/3422
#
# Processing point 779/3422
#
# Processing point 780/3422
#
# Processing point 781/3422
#
# Processing point 782/3422
#
# Processing point 783/3422
#
# Processing point 784/3422
#
# Processing point 785/3422
#
# Processing point 786/3422
#
# Processing point 787/3422
#
# Processing point 788/3422
#
# Processing point 789/3422
#
# Processing point 790/3422
#
# Processing point 791/3422
#
# Processing point 792/3422
#
# Processing point 793/3422
#
# Processing point 794/3422
#
# Processing point 795/3422
#
# Processing point 796/3422
#
# Processing point 797/3422
#
# Processing point 798/3422
#
# Processing point 799/3422
#
# Processing point 800/3422
#
# Processing point 801/3422
#
# Processing point 802/3422
#
# Processing point 803/3422
#
# Processing point 804/3422
#
# Processing point 805/3422
#
# Processing point 806/3422
#
# Processing point 807/3422
#
# Processing point 808/3422
#
# Processing point 809/3422
#
# Processing point 810/3422
#
# Processing point 811/3422
#
# Processing point 812/3422
#
# Processing point 813/3422
#
# Processing point 814/3422
#
# Processing point 815/3422
#
# Processing point 816/3422
#
# Processing point 817/3422
#
# Processing point 818/3422
#
# Processing point 819/3422
#
# Processing point 820/3422
#
# Processing point 821/3422
#
# Processing point 822/3422
#
# Processing point 823/3422
#
# Processing point 824/3422
#
# Processing point 825/3422
#
# Processing point 826/3422
#
# Processing point 827/3422
#
# Processing point 828/3422
#
# Processing point 829/3422
#
# Processing point 830/3422
#
# Processing point 831/3422
#
# Processing point 832/3422
#
# Processing point 833/3422
#
# Processing point 834/3422
#
# Processing point 835/3422
#
# Processing point 836/3422
#
# Processing point 837/3422
#
# Processing point 838/3422
#
# Processing point 839/3422
#
# Processing point 840/3422
#
# Processing point 841/3422
#
# Processing point 842/3422
#
# Processing point 843/3422
#
# Processing point 844/3422
#
# Processing point 845/3422
#
# Processing point 846/3422
#
# Processing point 847/3422
#
# Processing point 848/3422
#
# Processing point 849/3422
#
# Processing point 850/3422
#
# Processing point 851/3422
#
# Processing point 852/3422
#
# Processing point 853/3422
#
# Processing point 854/3422
#
# Processing point 855/3422
#
# Processing point 856/3422
#
# Processing point 857/3422
#
# Processing point 858/3422
#
# Processing point 859/3422
#
# Processing point 860/3422
#
# Processing point 861/3422
#
# Processing point 862/3422
#
# Processing point 863/3422
#
# Processing point 864/3422
#
# Processing point 865/3422
#
# Processing point 866/3422
#
# Processing point 867/3422
#
# Processing point 868/3422
#
# Processing point 869/3422
#
# Processing point 870/3422
#
# Processing point 871/3422
#
# Processing point 872/3422
#
# Processing point 873/3422
#
# Processing point 874/3422
#
# Processing point 875/3422
#
# Processing point 876/3422
#
# Processing point 877/3422
#
# Processing point 878/3422
#
# Processing point 879/3422
#
# Processing point 880/3422
#
# Processing point 881/3422
#
# Processing point 882/3422
#
# Processing point 883/3422
#
# Processing point 884/3422
#
# Processing point 885/3422
#
# Processing point 886/3422
#
# Processing point 887/3422
#
# Processing point 888/3422
#
# Processing point 889/3422
#
# Processing point 890/3422
#
# Processing point 891/3422
#
# Processing point 892/3422
#
# Processing point 893/3422
#
# Processing point 894/3422
#
# Processing point 895/3422
#
# Processing point 896/3422
#
# Processing point 897/3422
#
# Processing point 898/3422
#
# Processing point 899/3422
#
# Processing point 900/3422
#
# Processing point 901/3422
#
# Processing point 902/3422
#
# Processing point 903/3422
#
# Processing point 904/3422
#
# Processing point 905/3422
#
# Processing point 906/3422
#
# Processing point 907/3422
#
# Processing point 908/3422
#
# Processing point 909/3422
#
# Processing point 910/3422
#
# Processing point 911/3422
#
# Processing point 912/3422
#
# Processing point 913/3422
#
# Processing point 914/3422
#
# Processing point 915/3422
#
# Processing point 916/3422
#
# Processing point 917/3422
#
# Processing point 918/3422
#
# Processing point 919/3422
#
# Processing point 920/3422
#
# Processing point 921/3422
#
# Processing point 922/3422
#
# Processing point 923/3422
#
# Processing point 924/3422
#
# Processing point 925/3422
#
# Processing point 926/3422
#
# Processing point 927/3422
#
# Processing point 928/3422
#
# Processing point 929/3422
#
# Processing point 930/3422
#
# Processing point 931/3422
#
# Processing point 932/3422
#
# Processing point 933/3422
#
# Processing point 934/3422
#
# Processing point 935/3422
#
# Processing point 936/3422
#
# Processing point 937/3422
#
# Processing point 938/3422
#
# Processing point 939/3422
#
# Processing point 940/3422
#
# Processing point 941/3422
#
# Processing point 942/3422
#
# Processing point 943/3422
#
# Processing point 944/3422
#
# Processing point 945/3422
#
# Processing point 946/3422
#
# Processing point 947/3422
#
# Processing point 948/3422
#
# Processing point 949/3422
#
# Processing point 950/3422
#
# Processing point 951/3422
#
# Processing point 952/3422
#
# Processing point 953/3422
#
# Processing point 954/3422
#
# Processing point 955/3422
#
# Processing point 956/3422
#
# Processing point 957/3422
#
# Processing point 958/3422
#
# Processing point 959/3422
#
# Processing point 960/3422
#
# Processing point 961/3422
#
# Processing point 962/3422
#
# Processing point 963/3422
#
# Processing point 964/3422
#
# Processing point 965/3422
#
# Processing point 966/3422
#
# Processing point 967/3422
#
# Processing point 968/3422
#
# Processing point 969/3422
#
# Processing point 970/3422
#
# Processing point 971/3422
#
# Processing point 972/3422
#
# Processing point 973/3422
#
# Processing point 974/3422
#
# Processing point 975/3422
#
# Processing point 976/3422
#
# Processing point 977/3422
#
# Processing point 978/3422
#
# Processing point 979/3422
#
# Processing point 980/3422
#
# Processing point 981/3422
#
# Processing point 982/3422
#
# Processing point 983/3422
#
# Processing point 984/3422
#
# Processing point 985/3422
#
# Processing point 986/3422
#
# Processing point 987/3422
#
# Processing point 988/3422
#
# Processing point 989/3422
#
# Processing point 990/3422
#
# Processing point 991/3422
#
# Processing point 992/3422
#
# Processing point 993/3422
#
# Processing point 994/3422
#
# Processing point 995/3422
#
# Processing point 996/3422
#
# Processing point 997/3422
#
# Processing point 998/3422
#
# Processing point 999/3422
#
# Processing point 1000/3422
#
# Processing point 1001/3422
#
# Processing point 1002/3422
#
# Processing point 1003/3422
#
# Processing point 1004/3422
#
# Processing point 1005/3422
#
# Processing point 1006/3422
#
# Processing point 1007/3422
#
# Processing point 1008/3422
#
# Processing point 1009/3422
#
# Processing point 1010/3422
#
# Processing point 1011/3422
#
# Processing point 1012/3422
#
# Processing point 1013/3422
#
# Processing point 1014/3422
#
# Processing point 1015/3422
#
# Processing point 1016/3422
#
# Processing point 1017/3422
#
# Processing point 1018/3422
#
# Processing point 1019/3422
#
# Processing point 1020/3422
#
# Processing point 1021/3422
#
# Processing point 1022/3422
#
# Processing point 1023/3422
#
# Processing point 1024/3422
#
# Processing point 1025/3422
#
# Processing point 1026/3422
#
# Processing point 1027/3422
#
# Processing point 1028/3422
#
# Processing point 1029/3422
#
# Processing point 1030/3422
#
# Processing point 1031/3422
#
# Processing point 1032/3422
#
# Processing point 1033/3422
#
# Processing point 1034/3422
#
# Processing point 1035/3422
#
# Processing point 1036/3422
#
# Processing point 1037/3422
#
# Processing point 1038/3422
#
# Processing point 1039/3422
#
# Processing point 1040/3422
#
# Processing point 1041/3422
#
# Processing point 1042/3422
#
# Processing point 1043/3422
#
# Processing point 1044/3422
#
# Processing point 1045/3422
#
# Processing point 1046/3422
#
# Processing point 1047/3422
#
# Processing point 1048/3422
#
# Processing point 1049/3422
#
# Processing point 1050/3422
#
# Processing point 1051/3422
#
# Processing point 1052/3422
#
# Processing point 1053/3422
#
# Processing point 1054/3422
#
# Processing point 1055/3422
#
# Processing point 1056/3422
#
# Processing point 1057/3422
#
# Processing point 1058/3422
#
# Processing point 1059/3422
#
# Processing point 1060/3422
#
# Processing point 1061/3422
#
# Processing point 1062/3422
#
# Processing point 1063/3422
#
# Processing point 1064/3422
#
# Processing point 1065/3422
#
# Processing point 1066/3422
#
# Processing point 1067/3422
#
# Processing point 1068/3422
#
# Processing point 1069/3422
#
# Processing point 1070/3422
#
# Processing point 1071/3422
#
# Processing point 1072/3422
#
# Processing point 1073/3422
#
# Processing point 1074/3422
#
# Processing point 1075/3422
#
# Processing point 1076/3422
#
# Processing point 1077/3422
#
# Processing point 1078/3422
#
# Processing point 1079/3422
#
# Processing point 1080/3422
#
# Processing point 1081/3422
#
# Processing point 1082/3422
#
# Processing point 1083/3422
#
# Processing point 1084/3422
#
# Processing point 1085/3422
#
# Processing point 1086/3422
#
# Processing point 1087/3422
#
# Processing point 1088/3422
#
# Processing point 1089/3422
#
# Processing point 1090/3422
#
# Processing point 1091/3422
#
# Processing point 1092/3422
#
# Processing point 1093/3422
#
# Processing point 1094/3422
#
# Processing point 1095/3422
#
# Processing point 1096/3422
#
# Processing point 1097/3422
#
# Processing point 1098/3422
#
# Processing point 1099/3422
#
# Processing point 1100/3422
#
# Processing point 1101/3422
#
# Processing point 1102/3422
#
# Processing point 1103/3422
#
# Processing point 1104/3422
#
# Processing point 1105/3422
#
# Processing point 1106/3422
#
# Processing point 1107/3422
#
# Processing point 1108/3422
#
# Processing point 1109/3422
#
# Processing point 1110/3422
#
# Processing point 1111/3422
#
# Processing point 1112/3422
#
# Processing point 1113/3422
#
# Processing point 1114/3422
#
# Processing point 1115/3422
#
# Processing point 1116/3422
#
# Processing point 1117/3422
#
# Processing point 1118/3422
#
# Processing point 1119/3422
#
# Processing point 1120/3422
#
# Processing point 1121/3422
#
# Processing point 1122/3422
#
# Processing point 1123/3422
#
# Processing point 1124/3422
#
# Processing point 1125/3422
#
# Processing point 1126/3422
#
# Processing point 1127/3422
#
# Processing point 1128/3422
#
# Processing point 1129/3422
#
# Processing point 1130/3422
#
# Processing point 1131/3422
#
# Processing point 1132/3422
#
# Processing point 1133/3422
#
# Processing point 1134/3422
#
# Processing point 1135/3422
#
# Processing point 1136/3422
#
# Processing point 1137/3422
#
# Processing point 1138/3422
#
# Processing point 1139/3422
#
# Processing point 1140/3422
#
# Processing point 1141/3422
#
# Processing point 1142/3422
#
# Processing point 1143/3422
#
# Processing point 1144/3422
#
# Processing point 1145/3422
#
# Processing point 1146/3422
#
# Processing point 1147/3422
#
# Processing point 1148/3422
#
# Processing point 1149/3422
#
# Processing point 1150/3422
#
# Processing point 1151/3422
#
# Processing point 1152/3422
#
# Processing point 1153/3422
#
# Processing point 1154/3422
#
# Processing point 1155/3422
#
# Processing point 1156/3422
#
# Processing point 1157/3422
#
# Processing point 1158/3422
#
# Processing point 1159/3422
#
# Processing point 1160/3422
#
# Processing point 1161/3422
#
# Processing point 1162/3422
#
# Processing point 1163/3422
#
# Processing point 1164/3422
#
# Processing point 1165/3422
#
# Processing point 1166/3422
#
# Processing point 1167/3422
#
# Processing point 1168/3422
#
# Processing point 1169/3422
#
# Processing point 1170/3422
#
# Processing point 1171/3422
#
# Processing point 1172/3422
#
# Processing point 1173/3422
#
# Processing point 1174/3422
#
# Processing point 1175/3422
#
# Processing point 1176/3422
#
# Processing point 1177/3422
#
# Processing point 1178/3422
#
# Processing point 1179/3422
#
# Processing point 1180/3422
#
# Processing point 1181/3422
#
# Processing point 1182/3422
#
# Processing point 1183/3422
#
# Processing point 1184/3422
#
# Processing point 1185/3422
#
# Processing point 1186/3422
#
# Processing point 1187/3422
#
# Processing point 1188/3422
#
# Processing point 1189/3422
#
# Processing point 1190/3422
#
# Processing point 1191/3422
#
# Processing point 1192/3422
#
# Processing point 1193/3422
#
# Processing point 1194/3422
#
# Processing point 1195/3422
#
# Processing point 1196/3422
#
# Processing point 1197/3422
#
# Processing point 1198/3422
#
# Processing point 1199/3422
#
# Processing point 1200/3422
#
# Processing point 1201/3422
#
# Processing point 1202/3422
#
# Processing point 1203/3422
#
# Processing point 1204/3422
#
# Processing point 1205/3422
#
# Processing point 1206/3422
#
# Processing point 1207/3422
#
# Processing point 1208/3422
#
# Processing point 1209/3422
#
# Processing point 1210/3422
#
# Processing point 1211/3422
#
# Processing point 1212/3422
#
# Processing point 1213/3422
#
# Processing point 1214/3422
#
# Processing point 1215/3422
#
# Processing point 1216/3422
#
# Processing point 1217/3422
#
# Processing point 1218/3422
#
# Processing point 1219/3422
#
# Processing point 1220/3422
#
# Processing point 1221/3422
#
# Processing point 1222/3422
#
# Processing point 1223/3422
#
# Processing point 1224/3422
#
# Processing point 1225/3422
#
# Processing point 1226/3422
#
# Processing point 1227/3422
#
# Processing point 1228/3422
#
# Processing point 1229/3422
#
# Processing point 1230/3422
#
# Processing point 1231/3422
#
# Processing point 1232/3422
#
# Processing point 1233/3422
#
# Processing point 1234/3422
#
# Processing point 1235/3422
#
# Processing point 1236/3422
#
# Processing point 1237/3422
#
# Processing point 1238/3422
#
# Processing point 1239/3422
#
# Processing point 1240/3422
#
# Processing point 1241/3422
#
# Processing point 1242/3422
#
# Processing point 1243/3422
#
# Processing point 1244/3422
#
# Processing point 1245/3422
#
# Processing point 1246/3422
#
# Processing point 1247/3422
#
# Processing point 1248/3422
#
# Processing point 1249/3422
#
# Processing point 1250/3422
#
# Processing point 1251/3422
#
# Processing point 1252/3422
#
# Processing point 1253/3422
#
# Processing point 1254/3422
#
# Processing point 1255/3422
#
# Processing point 1256/3422
#
# Processing point 1257/3422
#
# Processing point 1258/3422
#
# Processing point 1259/3422
#
# Processing point 1260/3422
#
# Processing point 1261/3422
#
# Processing point 1262/3422
#
# Processing point 1263/3422
#
# Processing point 1264/3422
#
# Processing point 1265/3422
#
# Processing point 1266/3422
#
# Processing point 1267/3422
#
# Processing point 1268/3422
#
# Processing point 1269/3422
#
# Processing point 1270/3422
#
# Processing point 1271/3422
#
# Processing point 1272/3422
#
# Processing point 1273/3422
#
# Processing point 1274/3422
#
# Processing point 1275/3422
#
# Processing point 1276/3422
#
# Processing point 1277/3422
#
# Processing point 1278/3422
#
# Processing point 1279/3422
#
# Processing point 1280/3422
#
# Processing point 1281/3422
#
# Processing point 1282/3422
#
# Processing point 1283/3422
#
# Processing point 1284/3422
#
# Processing point 1285/3422
#
# Processing point 1286/3422
#
# Processing point 1287/3422
#
# Processing point 1288/3422
#
# Processing point 1289/3422
#
# Processing point 1290/3422
#
# Processing point 1291/3422
#
# Processing point 1292/3422
#
# Processing point 1293/3422
#
# Processing point 1294/3422
#
# Processing point 1295/3422
#
# Processing point 1296/3422
#
# Processing point 1297/3422
#
# Processing point 1298/3422
#
# Processing point 1299/3422
#
# Processing point 1300/3422
#
# Processing point 1301/3422
#
# Processing point 1302/3422
#
# Processing point 1303/3422
#
# Processing point 1304/3422
#
# Processing point 1305/3422
#
# Processing point 1306/3422
#
# Processing point 1307/3422
#
# Processing point 1308/3422
#
# Processing point 1309/3422
#
# Processing point 1310/3422
#
# Processing point 1311/3422
#
# Processing point 1312/3422
#
# Processing point 1313/3422
#
# Processing point 1314/3422
#
# Processing point 1315/3422
#
# Processing point 1316/3422
#
# Processing point 1317/3422
#
# Processing point 1318/3422
#
# Processing point 1319/3422
#
# Processing point 1320/3422
#
# Processing point 1321/3422
#
# Processing point 1322/3422
#
# Processing point 1323/3422
#
# Processing point 1324/3422
#
# Processing point 1325/3422
#
# Processing point 1326/3422
#
# Processing point 1327/3422
#
# Processing point 1328/3422
#
# Processing point 1329/3422
#
# Processing point 1330/3422
#
# Processing point 1331/3422
#
# Processing point 1332/3422
#
# Processing point 1333/3422
#
# Processing point 1334/3422
#
# Processing point 1335/3422
#
# Processing point 1336/3422
#
# Processing point 1337/3422
#
# Processing point 1338/3422
#
# Processing point 1339/3422
#
# Processing point 1340/3422
#
# Processing point 1341/3422
#
# Processing point 1342/3422
#
# Processing point 1343/3422
#
# Processing point 1344/3422
#
# Processing point 1345/3422
#
# Processing point 1346/3422
#
# Processing point 1347/3422
#
# Processing point 1348/3422
#
# Processing point 1349/3422
#
# Processing point 1350/3422
#
# Processing point 1351/3422
#
# Processing point 1352/3422
#
# Processing point 1353/3422
#
# Processing point 1354/3422
#
# Processing point 1355/3422
#
# Processing point 1356/3422
#
# Processing point 1357/3422
#
# Processing point 1358/3422
#
# Processing point 1359/3422
#
# Processing point 1360/3422
#
# Processing point 1361/3422
#
# Processing point 1362/3422
#
# Processing point 1363/3422
#
# Processing point 1364/3422
#
# Processing point 1365/3422
#
# Processing point 1366/3422
#
# Processing point 1367/3422
#
# Processing point 1368/3422
#
# Processing point 1369/3422
#
# Processing point 1370/3422
#
# Processing point 1371/3422
#
# Processing point 1372/3422
#
# Processing point 1373/3422
#
# Processing point 1374/3422
#
# Processing point 1375/3422
#
# Processing point 1376/3422
#
# Processing point 1377/3422
#
# Processing point 1378/3422
#
# Processing point 1379/3422
#
# Processing point 1380/3422
#
# Processing point 1381/3422
#
# Processing point 1382/3422
#
# Processing point 1383/3422
#
# Processing point 1384/3422
#
# Processing point 1385/3422
#
# Processing point 1386/3422
#
# Processing point 1387/3422
#
# Processing point 1388/3422
#
# Processing point 1389/3422
#
# Processing point 1390/3422
#
# Processing point 1391/3422
#
# Processing point 1392/3422
#
# Processing point 1393/3422
#
# Processing point 1394/3422
#
# Processing point 1395/3422
#
# Processing point 1396/3422
#
# Processing point 1397/3422
#
# Processing point 1398/3422
#
# Processing point 1399/3422
#
# Processing point 1400/3422
#
# Processing point 1401/3422
#
# Processing point 1402/3422
#
# Processing point 1403/3422
#
# Processing point 1404/3422
#
# Processing point 1405/3422
#
# Processing point 1406/3422
#
# Processing point 1407/3422
#
# Processing point 1408/3422
#
# Processing point 1409/3422
#
# Processing point 1410/3422
#
# Processing point 1411/3422
#
# Processing point 1412/3422
#
# Processing point 1413/3422
#
# Processing point 1414/3422
#
# Processing point 1415/3422
#
# Processing point 1416/3422
#
# Processing point 1417/3422
#
# Processing point 1418/3422
#
# Processing point 1419/3422
#
# Processing point 1420/3422
#
# Processing point 1421/3422
#
# Processing point 1422/3422
#
# Processing point 1423/3422
#
# Processing point 1424/3422
#
# Processing point 1425/3422
#
# Processing point 1426/3422
#
# Processing point 1427/3422
#
# Processing point 1428/3422
#
# Processing point 1429/3422
#
# Processing point 1430/3422
#
# Processing point 1431/3422
#
# Processing point 1432/3422
#
# Processing point 1433/3422
#
# Processing point 1434/3422
#
# Processing point 1435/3422
#
# Processing point 1436/3422
#
# Processing point 1437/3422
#
# Processing point 1438/3422
#
# Processing point 1439/3422
#
# Processing point 1440/3422
#
# Processing point 1441/3422
#
# Processing point 1442/3422
#
# Processing point 1443/3422
#
# Processing point 1444/3422
#
# Processing point 1445/3422
#
# Processing point 1446/3422
#
# Processing point 1447/3422
#
# Processing point 1448/3422
#
# Processing point 1449/3422
#
# Processing point 1450/3422
#
# Processing point 1451/3422
#
# Processing point 1452/3422
#
# Processing point 1453/3422
#
# Processing point 1454/3422
#
# Processing point 1455/3422
#
# Processing point 1456/3422
#
# Processing point 1457/3422
#
# Processing point 1458/3422
#
# Processing point 1459/3422
#
# Processing point 1460/3422
#
# Processing point 1461/3422
#
# Processing point 1462/3422
#
# Processing point 1463/3422
#
# Processing point 1464/3422
#
# Processing point 1465/3422
#
# Processing point 1466/3422
#
# Processing point 1467/3422
#
# Processing point 1468/3422
#
# Processing point 1469/3422
#
# Processing point 1470/3422
#
# Processing point 1471/3422
#
# Processing point 1472/3422
#
# Processing point 1473/3422
#
# Processing point 1474/3422
#
# Processing point 1475/3422
#
# Processing point 1476/3422
#
# Processing point 1477/3422
#
# Processing point 1478/3422
#
# Processing point 1479/3422
#
# Processing point 1480/3422
#
# Processing point 1481/3422
#
# Processing point 1482/3422
#
# Processing point 1483/3422
#
# Processing point 1484/3422
#
# Processing point 1485/3422
#
# Processing point 1486/3422
#
# Processing point 1487/3422
#
# Processing point 1488/3422
#
# Processing point 1489/3422
#
# Processing point 1490/3422
#
# Processing point 1491/3422
#
# Processing point 1492/3422
#
# Processing point 1493/3422
#
# Processing point 1494/3422
#
# Processing point 1495/3422
#
# Processing point 1496/3422
#
# Processing point 1497/3422
#
# Processing point 1498/3422
#
# Processing point 1499/3422
#
# Processing point 1500/3422
#
# Processing point 1501/3422
#
# Processing point 1502/3422
#
# Processing point 1503/3422
#
# Processing point 1504/3422
#
# Processing point 1505/3422
#
# Processing point 1506/3422
#
# Processing point 1507/3422
#
# Processing point 1508/3422
#
# Processing point 1509/3422
#
# Processing point 1510/3422
#
# Processing point 1511/3422
#
# Processing point 1512/3422
#
# Processing point 1513/3422
#
# Processing point 1514/3422
#
# Processing point 1515/3422
#
# Processing point 1516/3422
#
# Processing point 1517/3422
#
# Processing point 1518/3422
#
# Processing point 1519/3422
#
# Processing point 1520/3422
#
# Processing point 1521/3422
#
# Processing point 1522/3422
#
# Processing point 1523/3422
#
# Processing point 1524/3422
#
# Processing point 1525/3422
#
# Processing point 1526/3422
#
# Processing point 1527/3422
#
# Processing point 1528/3422
#
# Processing point 1529/3422
#
# Processing point 1530/3422
#
# Processing point 1531/3422
#
# Processing point 1532/3422
#
# Processing point 1533/3422
#
# Processing point 1534/3422
#
# Processing point 1535/3422
#
# Processing point 1536/3422
#
# Processing point 1537/3422
#
# Processing point 1538/3422
#
# Processing point 1539/3422
#
# Processing point 1540/3422
#
# Processing point 1541/3422
#
# Processing point 1542/3422
#
# Processing point 1543/3422
#
# Processing point 1544/3422
#
# Processing point 1545/3422
#
# Processing point 1546/3422
#
# Processing point 1547/3422
#
# Processing point 1548/3422
#
# Processing point 1549/3422
#
# Processing point 1550/3422
#
# Processing point 1551/3422
#
# Processing point 1552/3422
#
# Processing point 1553/3422
#
# Processing point 1554/3422
#
# Processing point 1555/3422
#
# Processing point 1556/3422
#
# Processing point 1557/3422
#
# Processing point 1558/3422
#
# Processing point 1559/3422
#
# Processing point 1560/3422
#
# Processing point 1561/3422
#
# Processing point 1562/3422
#
# Processing point 1563/3422
#
# Processing point 1564/3422
#
# Processing point 1565/3422
#
# Processing point 1566/3422
#
# Processing point 1567/3422
#
# Processing point 1568/3422
#
# Processing point 1569/3422
#
# Processing point 1570/3422
#
# Processing point 1571/3422
#
# Processing point 1572/3422
#
# Processing point 1573/3422
#
# Processing point 1574/3422
#
# Processing point 1575/3422
#
# Processing point 1576/3422
#
# Processing point 1577/3422
#
# Processing point 1578/3422
#
# Processing point 1579/3422
#
# Processing point 1580/3422
#
# Processing point 1581/3422
#
# Processing point 1582/3422
#
# Processing point 1583/3422
#
# Processing point 1584/3422
#
# Processing point 1585/3422
#
# Processing point 1586/3422
#
# Processing point 1587/3422
#
# Processing point 1588/3422
#
# Processing point 1589/3422
#
# Processing point 1590/3422
#
# Processing point 1591/3422
#
# Processing point 1592/3422
#
# Processing point 1593/3422
#
# Processing point 1594/3422
#
# Processing point 1595/3422
#
# Processing point 1596/3422
#
# Processing point 1597/3422
#
# Processing point 1598/3422
#
# Processing point 1599/3422
#
# Processing point 1600/3422
#
# Processing point 1601/3422
#
# Processing point 1602/3422
#
# Processing point 1603/3422
#
# Processing point 1604/3422
#
# Processing point 1605/3422
#
# Processing point 1606/3422
#
# Processing point 1607/3422
#
# Processing point 1608/3422
#
# Processing point 1609/3422
#
# Processing point 1610/3422
#
# Processing point 1611/3422
#
# Processing point 1612/3422
#
# Processing point 1613/3422
#
# Processing point 1614/3422
#
# Processing point 1615/3422
#
# Processing point 1616/3422
#
# Processing point 1617/3422
#
# Processing point 1618/3422
#
# Processing point 1619/3422
#
# Processing point 1620/3422
#
# Processing point 1621/3422
#
# Processing point 1622/3422
#
# Processing point 1623/3422
#
# Processing point 1624/3422
#
# Processing point 1625/3422
#
# Processing point 1626/3422
#
# Processing point 1627/3422
#
# Processing point 1628/3422
#
# Processing point 1629/3422
#
# Processing point 1630/3422
#
# Processing point 1631/3422
#
# Processing point 1632/3422
#
# Processing point 1633/3422
#
# Processing point 1634/3422
#
# Processing point 1635/3422
#
# Processing point 1636/3422
#
# Processing point 1637/3422
#
# Processing point 1638/3422
#
# Processing point 1639/3422
#
# Processing point 1640/3422
#
# Processing point 1641/3422
#
# Processing point 1642/3422
#
# Processing point 1643/3422
#
# Processing point 1644/3422
#
# Processing point 1645/3422
#
# Processing point 1646/3422
#
# Processing point 1647/3422
#
# Processing point 1648/3422
#
# Processing point 1649/3422
#
# Processing point 1650/3422
#
# Processing point 1651/3422
#
# Processing point 1652/3422
#
# Processing point 1653/3422
#
# Processing point 1654/3422
#
# Processing point 1655/3422
#
# Processing point 1656/3422
#
# Processing point 1657/3422
#
# Processing point 1658/3422
#
# Processing point 1659/3422
#
# Processing point 1660/3422
#
# Processing point 1661/3422
#
# Processing point 1662/3422
#
# Processing point 1663/3422
#
# Processing point 1664/3422
#
# Processing point 1665/3422
#
# Processing point 1666/3422
#
# Processing point 1667/3422
#
# Processing point 1668/3422
#
# Processing point 1669/3422
#
# Processing point 1670/3422
#
# Processing point 1671/3422
#
# Processing point 1672/3422
#
# Processing point 1673/3422
#
# Processing point 1674/3422
#
# Processing point 1675/3422
#
# Processing point 1676/3422
#
# Processing point 1677/3422
#
# Processing point 1678/3422
#
# Processing point 1679/3422
#
# Processing point 1680/3422
#
# Processing point 1681/3422
#
# Processing point 1682/3422
#
# Processing point 1683/3422
#
# Processing point 1684/3422
#
# Processing point 1685/3422
#
# Processing point 1686/3422
#
# Processing point 1687/3422
#
# Processing point 1688/3422
#
# Processing point 1689/3422
#
# Processing point 1690/3422
#
# Processing point 1691/3422
#
# Processing point 1692/3422
#
# Processing point 1693/3422
#
# Processing point 1694/3422
#
# Processing point 1695/3422
#
# Processing point 1696/3422
#
# Processing point 1697/3422
#
# Processing point 1698/3422
#
# Processing point 1699/3422
#
# Processing point 1700/3422
#
# Processing point 1701/3422
#
# Processing point 1702/3422
#
# Processing point 1703/3422
#
# Processing point 1704/3422
#
# Processing point 1705/3422
#
# Processing point 1706/3422
#
# Processing point 1707/3422
#
# Processing point 1708/3422
#
# Processing point 1709/3422
#
# Processing point 1710/3422
#
# Processing point 1711/3422
#
# Processing point 1712/3422
#
# Processing point 1713/3422
#
# Processing point 1714/3422
#
# Processing point 1715/3422
#
# Processing point 1716/3422
#
# Processing point 1717/3422
#
# Processing point 1718/3422
#
# Processing point 1719/3422
#
# Processing point 1720/3422
#
# Processing point 1721/3422
#
# Processing point 1722/3422
#
# Processing point 1723/3422
#
# Processing point 1724/3422
#
# Processing point 1725/3422
#
# Processing point 1726/3422
#
# Processing point 1727/3422
#
# Processing point 1728/3422
#
# Processing point 1729/3422
#
# Processing point 1730/3422
#
# Processing point 1731/3422
#
# Processing point 1732/3422
#
# Processing point 1733/3422
#
# Processing point 1734/3422
#
# Processing point 1735/3422
#
# Processing point 1736/3422
#
# Processing point 1737/3422
#
# Processing point 1738/3422
#
# Processing point 1739/3422
#
# Processing point 1740/3422
#
# Processing point 1741/3422
#
# Processing point 1742/3422
#
# Processing point 1743/3422
#
# Processing point 1744/3422
#
# Processing point 1745/3422
#
# Processing point 1746/3422
#
# Processing point 1747/3422
#
# Processing point 1748/3422
#
# Processing point 1749/3422
#
# Processing point 1750/3422
#
# Processing point 1751/3422
#
# Processing point 1752/3422
#
# Processing point 1753/3422
#
# Processing point 1754/3422
#
# Processing point 1755/3422
#
# Processing point 1756/3422
#
# Processing point 1757/3422
#
# Processing point 1758/3422
#
# Processing point 1759/3422
#
# Processing point 1760/3422
#
# Processing point 1761/3422
#
# Processing point 1762/3422
#
# Processing point 1763/3422
#
# Processing point 1764/3422
#
# Processing point 1765/3422
#
# Processing point 1766/3422
#
# Processing point 1767/3422
#
# Processing point 1768/3422
#
# Processing point 1769/3422
#
# Processing point 1770/3422
#
# Processing point 1771/3422
#
# Processing point 1772/3422
#
# Processing point 1773/3422
#
# Processing point 1774/3422
#
# Processing point 1775/3422
#
# Processing point 1776/3422
#
# Processing point 1777/3422
#
# Processing point 1778/3422
#
# Processing point 1779/3422
#
# Processing point 1780/3422
#
# Processing point 1781/3422
#
# Processing point 1782/3422
#
# Processing point 1783/3422
#
# Processing point 1784/3422
#
# Processing point 1785/3422
#
# Processing point 1786/3422
#
# Processing point 1787/3422
#
# Processing point 1788/3422
#
# Processing point 1789/3422
#
# Processing point 1790/3422
#
# Processing point 1791/3422
#
# Processing point 1792/3422
#
# Processing point 1793/3422
#
# Processing point 1794/3422
#
# Processing point 1795/3422
#
# Processing point 1796/3422
#
# Processing point 1797/3422
#
# Processing point 1798/3422
#
# Processing point 1799/3422
#
# Processing point 1800/3422
#
# Processing point 1801/3422
#
# Processing point 1802/3422
#
# Processing point 1803/3422
#
# Processing point 1804/3422
#
# Processing point 1805/3422
#
# Processing point 1806/3422
#
# Processing point 1807/3422
#
# Processing point 1808/3422
#
# Processing point 1809/3422
#
# Processing point 1810/3422
#
# Processing point 1811/3422
#
# Processing point 1812/3422
#
# Processing point 1813/3422
#
# Processing point 1814/3422
#
# Processing point 1815/3422
#
# Processing point 1816/3422
#
# Processing point 1817/3422
#
# Processing point 1818/3422
#
# Processing point 1819/3422
#
# Processing point 1820/3422
#
# Processing point 1821/3422
#
# Processing point 1822/3422
#
# Processing point 1823/3422
#
# Processing point 1824/3422
#
# Processing point 1825/3422
#
# Processing point 1826/3422
#
# Processing point 1827/3422
#
# Processing point 1828/3422
#
# Processing point 1829/3422
#
# Processing point 1830/3422
#
# Processing point 1831/3422
#
# Processing point 1832/3422
#
# Processing point 1833/3422
#
# Processing point 1834/3422
#
# Processing point 1835/3422
#
# Processing point 1836/3422
#
# Processing point 1837/3422
#
# Processing point 1838/3422
#
# Processing point 1839/3422
#
# Processing point 1840/3422
#
# Processing point 1841/3422
#
# Processing point 1842/3422
#
# Processing point 1843/3422
#
# Processing point 1844/3422
#
# Processing point 1845/3422
#
# Processing point 1846/3422
#
# Processing point 1847/3422
#
# Processing point 1848/3422
#
# Processing point 1849/3422
#
# Processing point 1850/3422
#
# Processing point 1851/3422
#
# Processing point 1852/3422
#
# Processing point 1853/3422
#
# Processing point 1854/3422
#
# Processing point 1855/3422
#
# Processing point 1856/3422
#
# Processing point 1857/3422
#
# Processing point 1858/3422
#
# Processing point 1859/3422
#
# Processing point 1860/3422
#
# Processing point 1861/3422
#
# Processing point 1862/3422
#
# Processing point 1863/3422
#
# Processing point 1864/3422
#
# Processing point 1865/3422
#
# Processing point 1866/3422
#
# Processing point 1867/3422
#
# Processing point 1868/3422
#
# Processing point 1869/3422
#
# Processing point 1870/3422
#
# Processing point 1871/3422
#
# Processing point 1872/3422
#
# Processing point 1873/3422
#
# Processing point 1874/3422
#
# Processing point 1875/3422
#
# Processing point 1876/3422
#
# Processing point 1877/3422
#
# Processing point 1878/3422
#
# Processing point 1879/3422
#
# Processing point 1880/3422
#
# Processing point 1881/3422
#
# Processing point 1882/3422
#
# Processing point 1883/3422
#
# Processing point 1884/3422
#
# Processing point 1885/3422
#
# Processing point 1886/3422
#
# Processing point 1887/3422
#
# Processing point 1888/3422
#
# Processing point 1889/3422
#
# Processing point 1890/3422
#
# Processing point 1891/3422
#
# Processing point 1892/3422
#
# Processing point 1893/3422
#
# Processing point 1894/3422
#
# Processing point 1895/3422
#
# Processing point 1896/3422
#
# Processing point 1897/3422
#
# Processing point 1898/3422
#
# Processing point 1899/3422
#
# Processing point 1900/3422
#
# Processing point 1901/3422
#
# Processing point 1902/3422
#
# Processing point 1903/3422
#
# Processing point 1904/3422
#
# Processing point 1905/3422
#
# Processing point 1906/3422
#
# Processing point 1907/3422
#
# Processing point 1908/3422
#
# Processing point 1909/3422
#
# Processing point 1910/3422
#
# Processing point 1911/3422
#
# Processing point 1912/3422
#
# Processing point 1913/3422
#
# Processing point 1914/3422
#
# Processing point 1915/3422
#
# Processing point 1916/3422
#
# Processing point 1917/3422
#
# Processing point 1918/3422
#
# Processing point 1919/3422
#
# Processing point 1920/3422
#
# Processing point 1921/3422
#
# Processing point 1922/3422
#
# Processing point 1923/3422
#
# Processing point 1924/3422
#
# Processing point 1925/3422
#
# Processing point 1926/3422
#
# Processing point 1927/3422
#
# Processing point 1928/3422
#
# Processing point 1929/3422
#
# Processing point 1930/3422
#
# Processing point 1931/3422
#
# Processing point 1932/3422
#
# Processing point 1933/3422
#
# Processing point 1934/3422
#
# Processing point 1935/3422
#
# Processing point 1936/3422
#
# Processing point 1937/3422
#
# Processing point 1938/3422
#
# Processing point 1939/3422
#
# Processing point 1940/3422
#
# Processing point 1941/3422
#
# Processing point 1942/3422
#
# Processing point 1943/3422
#
# Processing point 1944/3422
#
# Processing point 1945/3422
#
# Processing point 1946/3422
#
# Processing point 1947/3422
#
# Processing point 1948/3422
#
# Processing point 1949/3422
#
# Processing point 1950/3422
#
# Processing point 1951/3422
#
# Processing point 1952/3422
#
# Processing point 1953/3422
#
# Processing point 1954/3422
#
# Processing point 1955/3422
#
# Processing point 1956/3422
#
# Processing point 1957/3422
#
# Processing point 1958/3422
#
# Processing point 1959/3422
#
# Processing point 1960/3422
#
# Processing point 1961/3422
#
# Processing point 1962/3422
#
# Processing point 1963/3422
#
# Processing point 1964/3422
#
# Processing point 1965/3422
#
# Processing point 1966/3422
#
# Processing point 1967/3422
#
# Processing point 1968/3422
#
# Processing point 1969/3422
#
# Processing point 1970/3422
#
# Processing point 1971/3422
#
# Processing point 1972/3422
#
# Processing point 1973/3422
#
# Processing point 1974/3422
#
# Processing point 1975/3422
#
# Processing point 1976/3422
#
# Processing point 1977/3422
#
# Processing point 1978/3422
#
# Processing point 1979/3422
#
# Processing point 1980/3422
#
# Processing point 1981/3422
#
# Processing point 1982/3422
#
# Processing point 1983/3422
#
# Processing point 1984/3422
#
# Processing point 1985/3422
#
# Processing point 1986/3422
#
# Processing point 1987/3422
#
# Processing point 1988/3422
#
# Processing point 1989/3422
#
# Processing point 1990/3422
#
# Processing point 1991/3422
#
# Processing point 1992/3422
#
# Processing point 1993/3422
#
# Processing point 1994/3422
#
# Processing point 1995/3422
#
# Processing point 1996/3422
#
# Processing point 1997/3422
#
# Processing point 1998/3422
#
# Processing point 1999/3422
#
# Processing point 2000/3422
